# %%
import pandas as pd

# %%
# Open the categorical dataframe we created before.

categorical = pd.read_csv('categorical.csv')
categorical.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy renew_offer_type sales_channel  \
# 0      Suburban        Married  Corporate           Offer1         Agent
# 1      Suburban         Single   Personal           Offer3         Agent
# 2      Suburban        Married   Personal           Offer1         Agent
# 3      Suburban        Married  Corporate           Offer1   Call Center
# 4         Rural         Single   Personal           Offer1         Agent
#
#    vehicle_class vehicle_size
# 0   Two-Door Car      Medsize
# 1  Four-Door Car      Medsize
# 2   Two-Door Car      Medsize
# 3            SUV      Medsize
# 4  Four-Door Car      Medsize

# %%
# Plot all the categorical variables with the proper plot. What can you see?
import seaborn as sns
import matplotlib.pyplot as plt
def plot(categorical):
    for column in categorical.columns:
        sns.histplot(x=column, data=categorical)
        plt.show()
plot(categorical)

# %%
# There might be some columns that seem to be redundant, check their values to be sure. What should we do with them? Make any changes you feel are necessary.

categorical = categorical.drop(['renew_offer_type','vehicle_class'], axis=1)
categorical.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy sales_channel vehicle_size
# 0      Suburban        Married  Corporate         Agent      Medsize
# 1      Suburban         Single   Personal         Agent      Medsize
# 2      Suburban        Married   Personal         Agent      Medsize
# 3      Suburban        Married  Corporate   Call Center      Medsize
# 4         Rural         Single   Personal         Agent      Medsize

# %%
# Plot time variable. Can you extract something from it?

customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
customer_df.groupby('Effective To Date')['Customer'].count().plot(legend = True)
# Out:
# <AxesSubplot:xlabel='Effective To Date'>

# %%
# The time variable can be useful. You shoud transform its data into a more useful form. Hint: Day, week, and month as integers might be useful.
customer_df['Effective To Date'] = pd.to_datetime(customer_df['Effective To Date'])

# %%
customer_df['Day'] = customer_df['Effective To Date'].dt.day
customer_df['Week'] = customer_df['Effective To Date'].dt.week
customer_df['Month'] = customer_df['Effective To Date'].dt.month
# Out:
# /var/folders/mx/3k6w74vn0pxcc87nvhftj7hr0000gn/T/ipykernel_16977/3282429474.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   customer_df['Week'] = customer_df['Effective To Date'].dt.week

# %%
customer_df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor        2011-02-24         Employed      F   56274  ...
# 1     Bachelor        2011-01-31       Unemployed      F       0  ...
# 2     Bachelor        2011-02-19         Employed      F   48767  ...
# 3     Bachelor        2011-01-20       Unemployed      M       0  ...
# 4     Bachelor        2011-02-03         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor        2011-02-10         Employed      M   71941  ...
# 9130   College        2011-02-12         Employed      F   21604  ...
# 9131  Bachelor        2011-02-06       Unemployed      M       0  ...
# 9132   College        2011-02-03         Employed      M   21941  ...
# 9133   College        2011-02-14       Unemployed      M       0  ...
#
#          Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0     Corporate Auto  Corporate L3            Offer1          Agent
# 1      Personal Auto   Personal L3            Offer3          Agent
# 2      Personal Auto   Personal L3            Offer1          Agent
# 3     Corporate Auto  Corporate L2            Offer1    Call Center
# 4      Personal Auto   Personal L1            Offer1          Agent
# ...              ...           ...               ...            ...
# 9129   Personal Auto   Personal L1            Offer2            Web
# 9130  Corporate Auto  Corporate L3            Offer1         Branch
# 9131  Corporate Auto  Corporate L2            Offer1         Branch
# 9132   Personal Auto   Personal L2            Offer3         Branch
# 9133  Corporate Auto  Corporate L3            Offer4    Call Center
#
#       Total Claim Amount  Vehicle Class  Vehicle Size Day Week Month
# 0             384.811147   Two-Door Car       Medsize  24    8     2
# 1            1131.464935  Four-Door Car       Medsize  31    5     1
# 2             566.472247   Two-Door Car       Medsize  19    7     2
# 3             529.881344            SUV       Medsize  20    3     1
# 4             138.130879  Four-Door Car       Medsize   3    5     2
# ...                  ...            ...           ...  ..  ...   ...
# 9129          198.234764  Four-Door Car       Medsize  10    6     2
# 9130          379.200000  Four-Door Car       Medsize  12    6     2
# 9131          790.784983  Four-Door Car       Medsize   6    5     2
# 9132          691.200000  Four-Door Car         Large   3    5     2
# 9133          369.600000   Two-Door Car       Medsize  14    7     2
#
# [9134 rows x 27 columns]
